# %% [markdown]
# ### 📈시계열 데이터 프로젝트(금융 시장의 수익률 분석 보고)

# %% [markdown]
# #### 해당 프로젝트에서는 GLD(금 ETF)와 APPLE의 수익률을 시각화 및 비교 분석을 진행해보도록 하겠습니다.

# %%
import yfinance as yf

columns = ['AAPL', 'GLD']

df = yf.download(columns, start='2008-01-02')['Adj Close'].round(4)
df
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Ticker          AAPL     GLD
# Date
# 2008-01-02    5.8911   84.86
# 2008-01-03    5.8938   85.57
# 2008-01-04    5.4439   85.13
# 2008-01-07    5.3711   84.77
# 2008-01-08    5.1779   86.78
# ...              ...     ...
# 2024-06-10  193.1200  213.54
# 2024-06-11  207.1500  214.15
# 2024-06-12  213.0700  214.72
# 2024-06-13  214.2400  212.97
# 2024-06-14  212.4900  215.73
#
# [4142 rows x 2 columns]

# %% [markdown]
# ### 📈 전체 기간 시각화
#
# 해당 그래프는 'Apple' 과 'GLD'의 전체 시각화를 해보았습니다.

# %%
import matplotlib.pyplot as plt

# %%
df.plot(figsize=(8, 10), subplots=True)
df.diff().plot(figsize=(8, 8), subplots=True)
plt.show()

# %% [markdown]
# ### 📈 변동률 log 시각화
# 다음으로는 변동률 그래프에 log를 취해 수익률로서 시각화 해보도록 하겠습니다.

# %%
import numpy as np

# %%
rate_df = np.log(df / df.shift(1))
rate_df
# Out:
# Ticker          AAPL       GLD
# Date
# 2008-01-02       NaN       NaN
# 2008-01-03  0.000458  0.008332
# 2008-01-04 -0.079405 -0.005155
# 2008-01-07 -0.013463 -0.004238
# 2008-01-08 -0.036633  0.023434
# ...              ...       ...
# 2024-06-10 -0.019333  0.009126
# 2024-06-11  0.070131  0.002853
# 2024-06-12  0.028178  0.002658
# 2024-06-13  0.005476 -0.008184
# 2024-06-14 -0.008202  0.012876
#
# [4142 rows x 2 columns]

# %% [markdown]
# ### 🤔해당 코드에서 'log'를 취하는 이유는
# 1. 편의성
#    >- 일반 수익률을 사용할 경우 복잡한 곱셈이 필요로 하기 때문에 손쉬운 계산을 할 수 있기 때문입니다.
# 2. 정규 분포
#    >- 로그를 취하는 경우 데이터가 정규 분포에 더 가까워지므로, 이를 기반으로 한 통계적 분석이 더 정확하고 신뢰성 있게 수행될 수 있습니다.

# %%
rate_df[['AAPL', 'GLD']].plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### 📈 일간 평균 변동률 시각화
# 다음으론 일간 변동률을 평균을 내어 시각화 해보도록 하겠습니다.

# %%
df.pct_change().mean().plot(kind='bar', figsize=(7, 5))
# Out:
# <Axes: xlabel='Ticker'>

# %% [markdown]
# ### 📋 시각화 분석
# ### 🍎 Apple
# 1. 장기적인 상승
# > - Apple 주식은 2008년 이후로 꾸준히 상승세를 보이고 있습니다. 특히, 2012년과 2019년 이후에 급격히 상승을 보여주고 있습니다.
# > - 2019년 하반기부터 2020년 초까지의 상승세는  iPhone 11 시리즈의 성공적인 출시와 강력한 재무 실적 발표와 관련이 큰것으로 보입니다.
# <div style="display: flex;">
#     <img src="./images/아이폰11미다시7.png" style="width: 500px; margin-right: 20px; margin-bottom: 5px">
#     <img src="./images/아이폰11미다시7-1.png" style="width: 500px; margin-bottom: 5px">
# </div>
# <div style="display: flex">
#     <img src="./images/아이폰11미다시6.png" style="width: 500px; margin-right: 20px; margin-bottom: 5px">
#     <img src="./images/아이폰11미다시6-1.png" style="width: 500px">
# </div>
#
# 2. 변동성 증가
#    > - Apple 주식의 일간 변동폭은 시간이 지남에 따라 점진적으로 증가하고 있습니다. 특힝 2020년 이후 변동성이 급격히 증가한것을 볼 수 있습니다.
#
# 3. 주요 변동 시기
#    > - 2020년 초 COVID-19 팬데믹 기간 동안 변동성이 크게 증가했습니다. 이 시기에는 글로벌 시장의 불확실성이 극대화되었기 때문에 Apple 주식도 큰 영향을 받은 것으로 보입니다.
# 4. 평균 일간 변동률
#    > - Apple 주식의 평균 일간 변동률은 약 0.1%로 나타났습니다.
#
# ### 🪙GLD
# 1. 안정된 변동
#    > - GLD는 금 가격을 추종하는 ETF로, 전반적으로 Apple 주식에 비해 변동성이 적고 안정적이빈다.
#    > - GLD의 일간 변동폭은 시간이 지남에 따라 큰 변화 없이 비교적 일관된 패턴을 보입니다.
# 2. 주요 변동시기
#    > - 2008년과 2020년에 변동성이 다소 증가 했습니다. 이는 2008년 금융 위기와 2020년 COVID-19 팬데믹 기간이었습니다.
# 3. 평균 일간 변동
#    > - GLD의 평균 일간 변동률은 약 0.05%로 나타났습니다.
# <div style="display: flex; margin-bottom: 10px;">
#     <img src="./images/금값미다시1.png" style="width: 400px; margin-right: 20px; margin-bottom: 5px">
#     <img src="./images/금값미다시1-1.png" style="width: 500px">
# </div>
# <div style="display: flex;">
#     <img src="./images/금값미다시2.png" style="width: 400px; margin-right: 20px; margin-bottom: 5px">
#     <img src="./images/금값미다시2-1.png" style="width: 500px">
# </div>
#
#
# ### 💡비교분석
# 1. 변동성
#    > - Apple은 시간이 지남에 따라 변동성이 증가하는 경향을 보입니다.
#    > - GLD는 상대적으로 변동성이 적고 안정적입니다. 경제 불확실성 시기에 다소 변동성이 증가하지만 전반적으로 일관된 패턴을 유지합니다.
# 2. 안정성
#    > - Apple은 높은 변동성을 보이지만, 이는 주로 기술주 특성과 글로벌 결제 상황에 따라 영향을 받는 것으로 보입니다.
#    > - GLD는 전통적으로 안전 자산으로 간주되며, 변동성이 적고 안정적인 성과를 보입니다.
# 3. 평균 일간 변동률
#    > - Apple은 평균 일간 변동률이 GLD에 비해 높아, 변동성이 큰 자산임을 알 수 있습니다.
#    > - GLD는 평균 일간 변동률이 낮아, 비교적 안정적인 자산임을 알 수 있습니다.

# %% [markdown]
# ---

# %% [markdown]
# ### 📈일간, 월간 수익률 그래프

# %% [markdown]
# 이번에는 'Apple'과 'GLD'의 일간, 월간 수익률을 시각화 해보도록 하겠습니다.

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

rate_df.cumsum().apply(np.exp).plot(figsize=(12, 4))
plt.title('APPLE과 GLD의 일간 수익률 그래프')
rate_df.cumsum().apply(np.exp).resample('1m').last().plot(figsize=(12, 4))
plt.title('APPLE과 GLD의 월간 수익률 그래프')
plt.show()

# %% [markdown]
# ### 📌비교
#
# 일간, 월간 수익률을 비교해 보았을 때,
# Apple은 2010년 이후 부터 수익률이 상승하고 있으며, GDL는 일정한 모습을 보이고 있습니다.

# %%
a_df = df[['AAPL']].dropna()
a_df
# Out:
# Ticker          AAPL
# Date
# 2008-01-02    5.8911
# 2008-01-03    5.8938
# 2008-01-04    5.4439
# 2008-01-07    5.3711
# 2008-01-08    5.1779
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [4142 rows x 1 columns]

# %%
window = 20

a_df['min'] = a_df['AAPL'].rolling(window=window).min()
a_df['mean'] = a_df['AAPL'].rolling(window=window).mean()
a_df['std'] = a_df['AAPL'].rolling(window=window).std()
a_df['median'] = a_df['AAPL'].rolling(window=window).median()
a_df['max'] = a_df['AAPL'].rolling(window=window).max()

a_df.dropna()
# Out:
# Ticker          AAPL       min       mean       std     median       max
# Date
# 2008-01-30    3.9966    3.9309    4.88696  0.656408    4.99490    5.8938
# 2008-01-31    4.0927    3.9309    4.79704  0.634424    4.87170    5.8938
# 2008-02-01    4.0440    3.9309    4.70455  0.600021    4.84570    5.4439
# 2008-02-04    3.9805    3.9309    4.63138  0.594316    4.76635    5.4243
# 2008-02-05    3.9113    3.9113    4.55839  0.588298    4.45540    5.4243
# ...              ...       ...        ...       ...        ...       ...
# 2024-06-10  193.1200  186.2800  191.34250  2.859656  190.97000  196.8900
# 2024-06-11  207.1500  186.8800  192.38600  4.339811  191.16500  207.1500
# 2024-06-12  213.0700  186.8800  193.66800  6.190998  191.77000  213.0700
# 2024-06-13  214.2400  186.8800  194.89400  7.628891  192.30000  214.2400
# 2024-06-14  212.4900  186.8800  196.02650  8.473565  192.73500  214.2400
#
# [4123 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

ax = a_df[['min', 'mean','median', 'max']].iloc[-252:].plot(figsize=(12, 6), style=['g--', 'r--', 'm--', 'g--'], lw=0.8)
a_df['AAPL'].iloc[-252:].plot(ax=ax)
plt.title("Apple의 20일 이동평균 가격 변동률")
plt.show()

# %%
a_df['SMA1'] = a_df['AAPL'].rolling(window=21).mean() #short-term
a_df['SMA2'] = a_df['AAPL'].rolling(window=252).mean() #long-term
a_df[['AAPL', 'SMA1', 'SMA2']].tail()
# Out:
# Ticker        AAPL        SMA1        SMA2
# Date
# 2024-06-10  193.12  190.947619  182.504918
# 2024-06-11  207.15  192.095238  182.611671
# 2024-06-12  213.07  193.370952  182.730731
# 2024-06-13  214.24  194.647619  182.856330
# 2024-06-14  212.49  195.731905  182.972456

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

a_df[['AAPL', 'SMA1', 'SMA2']].plot(figsize=(12, 6))
plt.title("Appl 단순 이동 평균 - 장기 및 단기")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

a_df.dropna(inplace=True)

a_df['positions'] = np.where(a_df['SMA1'] > a_df['SMA2'], 1, -1)  # 1: buy , -1: sell /

ax = a_df[['AAPL', 'SMA1', 'SMA2', 'positions']].plot(figsize=(15, 6), secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((-0.05, 1))

plt.title("기술적 분석을 기반으로 한 Apple 거래 창구")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 📌전처리(ACF, PACF)

# %% [markdown]
# ### 🍎 Apple

# %%
apple_stock_df = df.copy()
apple_stock_df = apple_stock_df.drop(labels='GLD', axis=1)
apple_stock_df
# Out:
# Ticker          AAPL
# Date
# 2008-01-02    5.8911
# 2008-01-03    5.8938
# 2008-01-04    5.4439
# 2008-01-07    5.3711
# 2008-01-08    5.1779
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [4142 rows x 1 columns]

# %%
apple_stock_diff_df = apple_stock_df.diff().dropna()
apple_stock_diff_df
# Out:
# Ticker         AAPL
# Date
# 2008-01-03   0.0027
# 2008-01-04  -0.4499
# 2008-01-07  -0.0728
# 2008-01-08  -0.1932
# 2008-01-09   0.2464
# ...             ...
# 2024-06-10  -3.7700
# 2024-06-11  14.0300
# 2024-06-12   5.9200
# 2024-06-13   1.1700
# 2024-06-14  -1.7500
#
# [4141 rows x 1 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

plot_acf(apple_stock_df, lags=20, ax=ax[0])
plot_acf(apple_stock_diff_df, lags=20, ax=ax[1])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

plot_pacf(apple_stock_df, lags=20, ax=ax[0])
plot_pacf(apple_stock_diff_df, lags=20, ax=ax[1])
plt.show()

# %% [markdown]
# ### 🪙GLD

# %%
gold_stock_df = df.copy()
gold_stock_df = gold_stock_df.drop(labels='AAPL', axis=1)
gold_stock_df
# Out:
# Ticker         GLD
# Date
# 2008-01-02   84.86
# 2008-01-03   85.57
# 2008-01-04   85.13
# 2008-01-07   84.77
# 2008-01-08   86.78
# ...            ...
# 2024-06-10  213.54
# 2024-06-11  214.15
# 2024-06-12  214.72
# 2024-06-13  212.97
# 2024-06-14  215.73
#
# [4142 rows x 1 columns]

# %%
gold_stock_diff_df = gold_stock_df.diff().dropna()
gold_stock_diff_df
# Out:
# Ticker       GLD
# Date
# 2008-01-03  0.71
# 2008-01-04 -0.44
# 2008-01-07 -0.36
# 2008-01-08  2.01
# 2008-01-09 -0.23
# ...          ...
# 2024-06-10  1.94
# 2024-06-11  0.61
# 2024-06-12  0.57
# 2024-06-13 -1.75
# 2024-06-14  2.76
#
# [4141 rows x 1 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

plot_acf(gold_stock_df, lags=20, ax=ax[0])
plot_acf(gold_stock_diff_df, lags=20, ax=ax[1])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

plot_pacf(gold_stock_df, lags=20, ax=ax[0])
plot_pacf(gold_stock_diff_df, lags=20, ax=ax[1])
plt.show()

# %% [markdown]
# ### 📌전처리 결과
# 1. Apple, GLD 모두lags=1에서 강한 단기 의존성을 보입니다.
# 2. 원 데이터는 여러 lags에서 유의미한 자기상관을 나태어 장기적인 의존성이 있음을 보여줍니다.
# 3. 차분을 통해 이러한 장기적인 의존성을 제거할 수 있으며, 이는 정상시계열로 만들 수 있습니다.

# %% [markdown]
# ---

# %% [markdown]
# ### 📈ARIMA 모델을 사용한 모델 평가 진행

# %%
df
# Out:
# Ticker          AAPL     GLD
# Date
# 2008-01-02    5.8911   84.86
# 2008-01-03    5.8938   85.57
# 2008-01-04    5.4439   85.13
# 2008-01-07    5.3711   84.77
# 2008-01-08    5.1779   86.78
# ...              ...     ...
# 2024-06-10  193.1200  213.54
# 2024-06-11  207.1500  214.15
# 2024-06-12  213.0700  214.72
# 2024-06-13  214.2400  212.97
# 2024-06-14  212.4900  215.73
#
# [4142 rows x 2 columns]

# %%
a_df1 = df.drop(columns=['GLD'])
a_df1
# Out:
# Ticker          AAPL
# Date
# 2008-01-02    5.8911
# 2008-01-03    5.8938
# 2008-01-04    5.4439
# 2008-01-07    5.3711
# 2008-01-08    5.1779
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [4142 rows x 1 columns]

# %%
a_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4142 entries, 2008-01-02 to 2024-06-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    4142 non-null   float64
# dtypes: float64(1)
# memory usage: 193.8 KB

# %%
a_df1 = a_df1.dropna()
a_df1 = a_df1['2023-01-03':]
a_df1
# Out:
# Ticker          AAPL
# Date
# 2023-01-03  124.2163
# 2023-01-04  125.4975
# 2023-01-05  124.1666
# 2023-01-06  128.7352
# 2023-01-09  129.2616
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [365 rows x 1 columns]

# %%
y_train = a_df1['AAPL'][:int(0.8 * len(a_df1))]
y_test = a_df1['AAPL'][int(0.8 * len(a_df1)):]

# %%
y_train.plot()
y_test.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from pmdarima.arima import ndiffs

kpss_diffs = ndiffs(y_train, alpha=0.05, test='kpss', max_d=10)
adf_diffs = ndiffs(y_train, alpha=0.05, test='adf', max_d=10)
pp_diffs = ndiffs(y_train, alpha=0.05, test='pp', max_d=10)

n_diffs = max(kpss_diffs, adf_diffs, pp_diffs)

print(n_diffs)
# Out:
# 1

# %%
import pmdarima as pm

model = pm. auto_arima(y=y_train, 
                       start_p=0, max_p=10, 
                       start_q=0, max_q=10, 
                       m=1, stepwise=True, 
                       trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1270.314, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1269.764, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1269.729, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1270.630, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1271.057, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1271.699, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1272.915, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1269.669, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1271.624, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1271.664, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1269.671, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1273.554, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 0.577 seconds

# %%
import matplotlib.pyplot as plt

model.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
prediction = model.predict(n_periods=len(y_test))
prediction
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 292    179.554862
# 293    179.554862
# 294    179.554862
# 295    179.554862
# 296    179.554862
#           ...
# 360    179.554862
# 361    179.554862
# 362    179.554862
# 363    179.554862
# 364    179.554862
# Length: 73, dtype: float64

# %%
prediction, conf_int = model.predict(n_periods=1, return_conf_int=True)
print(conf_int)
print(prediction)
# Out:
# [[175.38178406 183.72793996]]
# 292    179.554862
# dtype: float64
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
prediction.tolist()[0]
# Out:
# 179.55486200649545

# %%
def predict_one_step():
    prediction = model.predict(n_periods=1)
    return prediction.tolist()[0]

# %%
p_list = []

for data in y_test:
    p = predict_one_step()
    p_list.append(p)

    model.update(data)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd

y_predict_df = pd.DataFrame({"test": y_test, "pred": p_list})
y_predict_df
# Out:
#               test        pred
# Date
# 2024-03-04  175.10  179.554862
# 2024-03-05  170.12  174.633112
# 2024-03-06  169.12  169.587787
# 2024-03-07  169.00  169.064054
# 2024-03-08  170.73  168.992250
# ...            ...         ...
# 2024-06-10  193.12  197.098439
# 2024-06-11  207.15  192.817731
# 2024-06-12  213.07  207.780302
# 2024-06-13  214.24  213.457602
# 2024-06-14  212.49  214.304518
#
# [73 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

plt.plot(y_train, label='Train')
plt.plot(y_test, label='Test')
plt.plot(y_predict_df.pred, label='Prediction')
plt.legend()
plt.show()

# %%
import numpy as np

def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f'MAPE (%): {MAPE(y_test, p_list):.4f}')
# Out:
# MAPE (%): 1.2073

# %%
window = 10

a_df1['min'] = a_df1['AAPL'].rolling(window=window).min()
a_df1['mean'] = a_df1['AAPL'].rolling(window=window).mean()
a_df1['std'] = a_df1['AAPL'].rolling(window=window).std()
a_df1['median'] = a_df1['AAPL'].rolling(window=window).median()
a_df1['max'] = a_df1['AAPL'].rolling(window=window).max()

a_df1.dropna()
# Out:
# Ticker          AAPL       min       mean       std     median       max
# Date
# 2023-01-17  135.0121  124.1666  129.56454  3.955204  129.54965  135.0121
# 2023-01-18  134.2871  124.1666  130.57162  3.717071  131.16855  135.0121
# 2023-01-19  134.3467  124.1666  131.45654  3.416029  132.53910  135.0121
# 2023-01-20  136.9289  128.7352  132.73277  2.698542  133.20950  136.9289
# 2023-01-23  140.1468  129.2616  133.87393  3.188590  134.06365  140.1468
# ...              ...       ...        ...       ...        ...       ...
# 2024-06-10  193.1200  189.9900  193.25600  2.301995  193.57500  196.8900
# 2024-06-11  207.1500  190.2900  194.97200  4.721376  194.19000  207.1500
# 2024-06-12  213.0700  191.2900  197.25000  7.105133  194.41500  213.0700
# 2024-06-13  214.2400  192.2500  199.54500  8.529781  195.17500  214.2400
# 2024-06-14  212.4900  193.1200  201.56900  8.995089  196.38000  214.2400
#
# [356 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

ax = a_df1[['min', 'mean', 'median', 'max']].iloc[-252:].plot(figsize=(12, 6), style=['g--', 'r--', 'm--', 'g--'], lw=0.8)
a_df1['AAPL'].iloc[-252:].plot(ax=ax)
plt.title("Apple 10일 가격 이동평균")
plt.show()

# %%
a_df1['SMA1'] = a_df1['AAPL'].rolling(window=21).mean() #short-term
a_df1['SMA2'] = a_df1['AAPL'].rolling(window=252).mean() #long-term
a_df1[['AAPL', 'SMA1', 'SMA2']]
# Out:
# Ticker          AAPL        SMA1        SMA2
# Date
# 2023-01-03  124.2163         NaN         NaN
# 2023-01-04  125.4975         NaN         NaN
# 2023-01-05  124.1666         NaN         NaN
# 2023-01-06  128.7352         NaN         NaN
# 2023-01-09  129.2616         NaN         NaN
# ...              ...         ...         ...
# 2024-06-10  193.1200  190.947619  182.504918
# 2024-06-11  207.1500  192.095238  182.611671
# 2024-06-12  213.0700  193.370952  182.730731
# 2024-06-13  214.2400  194.647619  182.856330
# 2024-06-14  212.4900  195.731905  182.972456
#
# [365 rows x 3 columns]

# %%
a_df1[['AAPL', 'SMA1', 'SMA2']].plot(figsize=(12, 6))
plt.title("Apple 단순 이동 평균 - 장기 및 단기")
plt.show()

# %%
a_df1.dropna(inplace=True)

a_df1['positions'] = np.where(a_df1['SMA1'] > a_df1['SMA2'], 1, -1)  # 1: buy , -1: sell /

ax = a_df1[['AAPL', 'SMA1', 'SMA2', 'positions']].plot(figsize=(15, 6), secondary_y='positions')
ax.get_legend().set_bbox_to_anchor((-0.05, 1))

plt.title("기술적 분석을 기반으로 한 Apple 거래 창구")
plt.show()

# %%
import numpy as np

def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f'MAPE (%): {MAPE(y_test, p_list):.4f}')
# Out:
# MAPE (%): 1.2073

# %% [markdown]
# ---

# %% [markdown]
# ### 📌 Deep Learning Phropet 사용

# %%
a_df2 = df.drop(columns=['GLD'])
a_df2
# Out:
# Ticker          AAPL
# Date
# 2008-01-02    5.8911
# 2008-01-03    5.8938
# 2008-01-04    5.4439
# 2008-01-07    5.3711
# 2008-01-08    5.1779
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [4142 rows x 1 columns]

# %%
a_df2 = a_df2['2022-01-01':]
a_df2
# Out:
# Ticker          AAPL
# Date
# 2022-01-03  179.7245
# 2022-01-04  177.4436
# 2022-01-05  172.7236
# 2022-01-06  169.8402
# 2022-01-07  170.0081
# ...              ...
# 2024-06-10  193.1200
# 2024-06-11  207.1500
# 2024-06-12  213.0700
# 2024-06-13  214.2400
# 2024-06-14  212.4900
#
# [616 rows x 1 columns]

# %%
pre_a_df = a_df2.reset_index()
pre_a_df
# Out:
# Ticker       Date      AAPL
# 0      2022-01-03  179.7245
# 1      2022-01-04  177.4436
# 2      2022-01-05  172.7236
# 3      2022-01-06  169.8402
# 4      2022-01-07  170.0081
# ..            ...       ...
# 611    2024-06-10  193.1200
# 612    2024-06-11  207.1500
# 613    2024-06-12  213.0700
# 614    2024-06-13  214.2400
# 615    2024-06-14  212.4900
#
# [616 rows x 2 columns]

# %%
pre_a_df = pre_a_df.rename(columns={'Date': 'ds'})
pre_a_df = pre_a_df.rename(columns={'AAPL': 'y'})
pre_a_df
# Out:
# Ticker         ds         y
# 0      2022-01-03  179.7245
# 1      2022-01-04  177.4436
# 2      2022-01-05  172.7236
# 3      2022-01-06  169.8402
# 4      2022-01-07  170.0081
# ..            ...       ...
# 611    2024-06-10  193.1200
# 612    2024-06-11  207.1500
# 613    2024-06-12  213.0700
# 614    2024-06-13  214.2400
# 615    2024-06-14  212.4900
#
# [616 rows x 2 columns]

# %%
pre_a_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      616 non-null    datetime64[ns]
#  1   y       616 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 9.8 KB

# %%
pre_a_df
# Out:
# Ticker         ds         y
# 0      2022-01-03  179.7245
# 1      2022-01-04  177.4436
# 2      2022-01-05  172.7236
# 3      2022-01-06  169.8402
# 4      2022-01-07  170.0081
# ..            ...       ...
# 611    2024-06-10  193.1200
# 612    2024-06-11  207.1500
# 613    2024-06-12  213.0700
# 614    2024-06-13  214.2400
# 615    2024-06-14  212.4900
#
# [616 rows x 2 columns]

# %%
train_df = pre_a_df.iloc[:int(len(pre_a_df) * 0.8)]
train_df
# Out:
# Ticker         ds         y
# 0      2022-01-03  179.7245
# 1      2022-01-04  177.4436
# 2      2022-01-05  172.7236
# 3      2022-01-06  169.8402
# 4      2022-01-07  170.0081
# ..            ...       ...
# 487    2023-12-11  192.9338
# 488    2023-12-12  194.4619
# 489    2023-12-13  197.7077
# 490    2023-12-14  197.8575
# 491    2023-12-15  197.3182
#
# [492 rows x 2 columns]

# %%
from prophet import Prophet
from prophet.diagnostics import cross_validation, performance_metrics
import itertools

# changepoint_prior_scale: trend의 변화하는 크기를 반영하는 정도이다, 0.05가 default
# seasonality_prior_scale: 계절성을 반영하는 단위이다.
# seasonality_mode: 계절성으로 나타나는 효과를 더해 나갈지, 곱해 나갈지 정한다.
search_space = {
    'changepoint_prior_scale': [0.05, 0.1, 0.5, 1.0, 5.0, 10.0],
    'seasonality_prior_scale': [0.05, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative']
}

# itertools.product(): 각 요소들의 모든 경우의 수 조합으로 생성
param_combinded = [dict(zip(search_space.keys(), v)) for v in itertools.product(*search_space.values())]

train_len = int(len(pre_a_df) * 0.8)
test_len = int(len(pre_a_df) * 0.2)

train_size = f'{train_len} days'
test_size = f'{test_len} days'
train_df = pre_a_df.iloc[: train_len]
test_df = pre_a_df.iloc[train_len: ]

mapes = []
for param in param_combinded:
    model = Prophet(**param)
    model.fit(train_df)

    # 'threads' 옵션은 메모리 사용량은 낮지만 CPU 바운드 작업에는 효과적이지 않을 수 있다.
    # 'dask' 옵션은 대규모의 데이터를 처리하는 데 효과적이다.
    # 'processes' 옵션은 각각의 작업을 별도의 프로세스로 실행하기 때문에 CPU 바운드 작업에 효과적이지만,
    # 메모리 사용량이 높을 수 있다.
    cv_df = cross_validation(model, initial=train_size, period='20 days', horizon=test_size, parallel='processes')
    df_p = performance_metrics(cv_df, rolling_window=1)
    mapes.append(df_p['mape'].values[0])

tuning_result = pd.DataFrame(param_combinded)
tuning_result['mape'] = mapes
# Out:
# 14:18:44 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:44 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:45 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:45 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:47 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:47 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:48 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:49 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:50 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:50 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:52 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:52 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:53 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:53 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:55 - cmdstanpy - INFO - Chain [1] start processing
# 14:18:55 - cmdstanpy - INFO - Chain [1] done processing
# 14:18:57 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %%
model = Prophet(changepoint_prior_scale=0.5, 
                seasonality_prior_scale=0.1, 
                seasonality_mode='additive')

model.fit(pre_a_df)
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
# 14:20:06 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:07 - cmdstanpy - INFO - Chain [1] done processing
#             ds        yhat  yhat_lower  yhat_upper
# 0   2022-01-03  172.793922  167.952069  177.976319
# 1   2022-01-04  172.258730  167.812327  177.183960
# 2   2022-01-05  171.749966  167.055309  177.087628
# 3   2022-01-06  171.109760  166.325639  175.865650
# 4   2022-01-07  170.911527  166.269519  175.860334
# ..         ...         ...         ...         ...
# 976 2025-06-10  269.598516 -123.046562  671.243792
# 977 2025-06-11  270.472284 -125.779690  674.755949
# 978 2025-06-12  271.169997 -130.545152  678.126951
# 979 2025-06-13  272.261078 -127.195219  678.786780
# 980 2025-06-14  273.436328 -125.919959  685.443962
#
# [981 rows x 4 columns]

# %%
a_df3 = pre_a_df.copy()
a_df3.set_index('ds', inplace=True)

forecast_df = forecast.copy()
forecast_df = forecast_df.set_index('ds')

a_df3.index = pd.to_datetime(a_df3.index)
forecast_df.index = pd.to_datetime(forecast_df.index)

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
plt.plot(a_df3[['y']], label='Train')
plt.plot(forecast_df[['yhat']], label='Prediction')
plt.legend()
plt.show()

# %%
model.plot(forecast, figsize=(15, 8), xlabel='year-month', ylabel='price')
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:94: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.tight_layout()
# ...

# %%
model.plot_components(forecast, figsize=(20, 20))
plt.show()
# Out:
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# C:\Users\user\AppData\Roaming\Python\Python311\site-packages\prophet\plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# ...

# %% [markdown]
# ### 📋시계열 데이터 시각화 분석
# 1. 주가의 전체 추이 및 예측
#    - 주가가 일정 기간 동안 약간의 변동을 보였으며, 예측 구간은 시간이 지남에 따라 넓어지며 불확실성이 증가하고 있음을 보여줍니다.
#
# 2. 요일별 주가 변화
#    - 주가는 일요일에 가장 높고, 목요일에 가장 낮습니다.
#    - 금요일과 토요일에는 목요일에 떨어졌던 주가가 다시 상승하는 경향을 보입니다.
#
# 3. 월별 주가 변화
#    - 1월에 높게 시작하여 3월까지 하락하는 경향이 있습니다.
#    - 5월부터 다시 상승하여 9월에 최고점을 찍습니다.
#      (이러한 이유는 2008년 ~ 2024년의 'Apple'의 'WWDC(신제품발표)'가 6월 초에 진행되고,
#      'iPhone' 신제품 1차 출시가 대략 9월 ~ 10월 사이에 진행되기 때문일 듯 합니다.)
#    - 이후 12월까지 변동을 보이며 다시 하락하는 경향을 나타냅니다.
#
# <div style="text-align: center;">
#     <img src="./images/WWDC.png" alt="WWDC" style="width: 500px;">
# </div>
# <div style="text-align: center;">
#     <span>('Apple'의 신제품 발표회인 'WWDC'는 모두 6월에 진행 되었으며, 2022년을 제외한 모든 개최 요일은 월요일이었습니다.)</span>
# </div>
#
# ### (🚨 이 전략은 과거 데이터에 기반한 것으로, 미래에도 동일한 패턴이 반복된다는 보장은 없습니다.)
#
# ### 💲종합적 매수 및 매도 전략
# 1. 단기 전략(요일별 패턴 기반)
# >-매수: 목요일
# >-매도: 금요일 또는 토요일
#
# 2. 중장기 전략(연중 패턴 기반)
# >- 매수: 3월
# >- 매도: 9월
